# %%
from PIL import Image
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

img = Image.open(r"E:\imgs\imgs\w_1.jpg")

plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.axis("off")
plt.savefig("sample_whale.png", bbox_inches="tight")
plt.close()

print("Saved image as sample_whale.png")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22668\2587909255.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
